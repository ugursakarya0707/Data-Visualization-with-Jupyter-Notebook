# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
game = pd.read_csv(r"C:\Users\uguur\OneDrive\Masaüstü\vgsales.csv")

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
game.dropna(how="any",inplace = True)
game.Year = game.Year.astype(int)
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16291 non-null int64
# Name            16291 non-null object
# Platform        16291 non-null object
# Year            16291 non-null int32
# Genre           16291 non-null object
# Publisher       16291 non-null object
# NA_Sales        16291 non-null float64
# EU_Sales        16291 non-null float64
# JP_Sales        16291 non-null float64
# Other_Sales     16291 non-null float64
# Global_Sales    16291 non-null float64
# dtypes: float64(5), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
category_order=["Action","Sports","Misc","Role-Playing","Shooter","Adventure","Racing","Platform","Simulation","Fighting","Strategy","Puzzle"]
plt.figure(figsize=(15,5))
sns.set(style="darkgrid")
sns.countplot(data=game,x="Genre",order=category_order)
plt.title("Which Genre Has Most Game in total")
plt.show()

# %%
game.loc[lambda df :df["Year"] > 2005.0] 
game_2005_af =game.loc[lambda df :df["Year"] > 2005.0] 
plt.figure(figsize=(15,5))
sns.set(style="darkgrid")
sns.countplot(data=game_2005_af,x="Year")
plt.title("Game Sales After 2005")
plt.show()

# %%
category_order=["Action","Sports","Misc","Role-Playing","Shooter","Adventure","Racing","Platform","Simulation","Fighting","Strategy","Puzzle"]
plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
plt.xticks(rotation=45)
sns.countplot(data=game_2005_be,x="Genre",order=category_order).set_title("Game sales in terms of genre before 2005")
plt.show()
category_order=["Action","Sports","Misc","Role-Playing","Shooter","Adventure","Racing","Platform","Simulation","Fighting","Strategy","Puzzle"]
plt.figure(figsize=(15,5))
plt.subplot(2,1,2)
plt.xticks(rotation=45)
sns.countplot(data=game_2005_af,x="Genre",order=category_order).set_title("Game sales in terms of genre after 2005")
plt.show()

# %%
##

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=game["Genre"][:10],y=game["Global_Sales"][:10].values);
ci=None

# %%
PS4 = game_2005_af.loc[game_2005_af['Platform'] == 'PS4']
PS4.head()
# Out:
#     Rank                            Name Platform  Year    Genre  \
# 33    34       Call of Duty: Black Ops 3      PS4  2015  Shooter
# 44    45              Grand Theft Auto V      PS4  2014   Action
# 77    78                         FIFA 16      PS4  2015   Sports
# 92    93    Star Wars Battlefront (2015)      PS4  2015  Shooter
# 93    94  Call of Duty: Advanced Warfare      PS4  2014  Shooter
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33            Activision      5.77      5.81      0.35         2.31
# 44  Take-Two Interactive      3.80      5.81      0.36         2.02
# 77       Electronic Arts      1.11      6.06      0.06         1.26
# 92       Electronic Arts      2.93      3.29      0.22         1.23
# 93            Activision      2.80      3.30      0.14         1.37
#
#     Global_Sales
# 33         14.24
# 44         11.98
# 77          8.49
# 92          7.67
# 93          7.60

# %%
Wii = game_2005_af.loc[game_2005_af["Platform"] == "Wii"]
Wii.head()
# Out:
#    Rank                       Name Platform  Year     Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006    Sports  Nintendo
# 2     3             Mario Kart Wii      Wii  2008    Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009    Sports  Nintendo
# 7     8                   Wii Play      Wii  2006      Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62

# %%
PS4.Genre.value_counts().plot(kind="pie",figsize=(15,7))
plt.title("PS4 Game Genre After 2005")
plt.ylabel("")
plt.show()

# %%
Wii.Genre.value_counts().plot(kind="pie",figsize=(15,7))
plt.title("Wii Game Genre After 2005")
plt.ylabel("")
plt.show()

# %%
game.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
Eu_Sales = game.groupby(['Publisher'])[['EU_Sales', 'Global_Sales']].sum().sort_values(by=['EU_Sales'], ascending=True)[-20:]
Eu_Sales.head()
# Out:
#                     EU_Sales  Global_Sales
# Publisher
# Atari                  25.80        146.77
# LucasArts              26.00         84.95
# Codemasters            28.65         47.77
# Bethesda Softworks     30.48         81.53
# Square Enix            32.57        144.73

# %%
Eu_Sales_PS4 = PS4.groupby(['Publisher'])[['EU_Sales', 'Global_Sales']].sum().sort_values(by=['EU_Sales'], ascending=True)[-20:]
Eu_Sales_PS4
# Out:
#                                         EU_Sales  Global_Sales
# Publisher
# Disney Interactive Studios                  0.60          1.28
# Sega                                        0.60          1.87
# Tecmo Koei                                  0.68          2.61
# Slightly Mad Studios                        0.69          1.04
# Hello Games                                 0.74          1.60
# 505 Games                                   0.78          1.42
# Deep Silver                                 0.84          1.86
# Capcom                                      0.88          2.60
# Codemasters                                 0.89          1.25
# Konami Digital Entertainment                3.03          6.93
# Sony Computer Entertainment Europe          3.59          7.52
# Square Enix                                 4.10         10.25
# Namco Bandai Games                          4.62         11.11
# Bethesda Softworks                          6.66         14.25
# ...
