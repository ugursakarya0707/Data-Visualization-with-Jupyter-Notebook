# %%
import pandas as pd
import numpy as np

# %%
house = pd.read_csv(r"C:\Users\uguur\OneDrive\Masaüstü\Yeni klasör (2)\.csv\kc_house_data.csv")

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
house[house["price"] >  180000.0 ].nunique()["zipcode"]
# Out:
# 70

# %%
###

# %%
cols = ["price","id"]
house[cols]
# Out:
#           price          id
# 0      221900.0  7129300520
# 1      538000.0  6414100192
# 2      180000.0  5631500400
# 3      604000.0  2487200875
# 4      510000.0  1954400510
# ...         ...         ...
# 21608  360000.0   263000018
# 21609  400000.0  6600060120
# 21610  402101.0  1523300141
# 21611  400000.0   291310100
# 21612  325000.0  1523300157
#
# [21613 rows x 2 columns]

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.sort_values(by= "price" ,ascending=False).head()
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house[house["zipcode"]  ==  98039]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 2974   3625049014  20140829T000000  2950000.0         4       3.50
# 3761   2540700110  20150212T000000  1905000.0         4       3.50
# 4077   3262300940  20141107T000000   875000.0         3       1.00
# 4078   3262300940  20150210T000000   940000.0         3       1.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 4791   2210500019  20150324T000000   937500.0         3       1.00
# 5178   6447300345  20150406T000000  1160000.0         4       3.00
# 5589   6447300225  20141106T000000  1880000.0         3       2.75
# 5880   2525049148  20141007T000000  3418800.0         5       5.00
# 6868   3262300235  20141126T000000  1555000.0         5       2.50
# 7501   2525049133  20150402T000000  1398000.0         5       2.25
# 8241   3262301355  20140725T000000  1320000.0         3       2.75
# ...

# %%
len(house[house["zipcode"]  ==  98039])
# Out:
# 50

# %%
## yukarısı

# %%
len(house.columns)
# Out:
# 21

# %%
cols = ["price","id"]
house[cols]
# Out:
#           price          id
# 0      221900.0  7129300520
# 1      538000.0  6414100192
# 2      180000.0  5631500400
# 3      604000.0  2487200875
# 4      510000.0  1954400510
# ...         ...         ...
# 21608  360000.0   263000018
# 21609  400000.0  6600060120
# 21610  402101.0  1523300141
# 21611  400000.0   291310100
# 21612  325000.0  1523300157
#
# [21613 rows x 2 columns]

# %%
cols
# Out:
# ['price', 'id']

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df2 =house.loc[:,"price":"zipcode"]

# %%
# Out:
# price            221900.0
# bedrooms              3.0
# bathrooms             1.0
# sqft_living        1180.0
# sqft_lot           5650.0
# floors                1.0
# waterfront            0.0
# view                  0.0
# condition             3.0
# grade                 7.0
# sqft_above         1180.0
# sqft_basement         0.0
# yr_built           1955.0
# yr_renovated          0.0
# zipcode           98178.0
# Name: 0, dtype: float64

# %%
house.shape
# Out:
# (21613, 21)

# %%
df2
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
kc =pd.concat([df2,house])
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
kc
# Out:
#        bathrooms  bedrooms  condition             date  floors  grade  \
# 0           1.00         3          3              NaN     1.0      7
# 1           2.25         3          3              NaN     2.0      7
# 2           1.00         2          3              NaN     1.0      6
# 3           3.00         4          5              NaN     1.0      7
# 4           2.00         3          3              NaN     1.0      8
# ...          ...       ...        ...              ...     ...    ...
# 21608       2.50         3          3  20140521T000000     3.0      8
# 21609       2.50         4          3  20150223T000000     2.0      8
# 21610       0.75         2          3  20140623T000000     2.0      7
# 21611       2.50         3          3  20150116T000000     2.0      8
# 21612       0.75         2          3  20141015T000000     2.0      7
#
#                  id      lat     long     price  ...  sqft_basement  \
# ...

# %%
kc.shape
# Out:
# (43226, 21)

# %%
kc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43226 entries, 0 to 21612
# Data columns (total 21 columns):
# bathrooms        43226 non-null float64
# bedrooms         43226 non-null int64
# condition        43226 non-null int64
# date             21613 non-null object
# floors           43226 non-null float64
# grade            43226 non-null int64
# id               21613 non-null float64
# lat              21613 non-null float64
# long             21613 non-null float64
# price            43226 non-null float64
# sqft_above       43226 non-null int64
# sqft_basement    43226 non-null int64
# sqft_living      43226 non-null int64
# sqft_living15    21613 non-null float64
# sqft_lot         43226 non-null int64
# sqft_lot15       21613 non-null float64
# view             43226 non-null int64
# waterfront       43226 non-null int64
# yr_built         43226 non-null int64
# yr_renovated     43226 non-null int64
# zipcode          43226 non-null int64
# ...

# %%
house.drop(labels = house.columns[0:2],axis =1 , inplace=True)

# %%
house
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...
